# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
# %matplotlib inline
import ipywidgets as widgets
from typing import Tuple
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import seaborn as sns
import sys
print("hallo world")
# Out:
# hallo world

# %%
Anka = pd.read_excel (r"O:\Naprave\Agrosta Wonderful-in drugi\X-Anka japka\Polifenoli Anka 18022020_3.xlsx", 0) #bere file
#print(Anka.columns) #naredi array z imeni stolpcev - izberemo katere od teh podatkov želimo prikazati
#nadaljujemo z ugotalvjanjem ukikatnih obravnavanj:
#print("Stolpec meso - deli merjeni: ", end =" "); print(pd.unique(Anka["meso"]))
#print("Sorta: ", end =" "); print(pd.unique(Anka["sorta"]))
#print(pd.unique(Anka["čas"]))
#print(pd.unique(Anka["lokacija"]))
#print(pd.unique(Anka["C-L"]))

h=Anka.columns #naredi matriko z imeniprva vrstica za imena
Anka1 = pd.DataFrame(Anka) #pretvori obliko v pandas
#print(type(Anka)) #če je <class 'pandas.core.frame.DataFrame'> bo delal naprej
#print(h)
##filtriraj podatke
meso = Anka.loc[(Anka['meso'] == 'meso') ]#  izloči kar ni zanimivo & (orders['Blok (Rimske I-VIII)'] == 'I')]
kozica = Anka.loc[(Anka['meso'] == 'kožica')]
list = Anka.loc[(Anka['meso'] == 'list')]
#dva = Zid.loc[(Zid['IZLOCITI'] == 0) ] # izloci oznacene

k = ['cryptochlorogenic acid', 'chlorogenic acid', 'catechin', 'epicatechin', 'neochlorogenic acid', 'Phlorizin', 'Procyanidin B1',
       'procyanidin B2_B4', 'Quercetin_13_1Rha', 'quercetin-13-1Glc_Gal',
       'p_1coumaric acid', 'Phloretin Xylo Glc',
       #'3_1Hydroxyphloretin',
       '3_1hydroxy_1Phlorizin', 'sum of hydroxycinnamic acids', 'sum of dihydrochalcones',
       'sum of flavonols', 'sum of flavanols' #'cy3_1gal'] #izberemo katere parametre želimo računati - Glej kaj natisne "h"
        ]
df = pd.DataFrame(columns=k) #ustvari prazno tabelo za podatke iz loopov
Ank = meso



def f(x):
    ll = Ank[x] #da kličemo vsak stolpec
    nn = 'test.' + ll.name +'.png'# naredimo string za poimenovanje datotek
    InLop = Ank.loc[(Ank[x] > 0)] #izbere samo tiste ki so večje od 0 - izloči besedilo
   #m = sum(InLop[x]) / len(InLop[x]) #povprečje
   #print(m)
    print(len(InLop[x]))
    yy=InLop[x]
     ## RIŠE BOXPLOT
#plt.close() #zapre vsak graf od prej
    fig, ax = plt.subplots()
    sns.boxplot(x="sorta", y=yy, hue="C-L", data=InLop, palette="Set3", ax=ax)  #hue="meso",
    plt.show() #prikaže vsak graf
   #fig = bp.get_figure()  # da graf v objekt fig
    print(nn)  # v  log izpiše ime grafa ki ga je naredil
   #fig.savefig(nn)  # shrani graf pod imenom "nn"
    return x
interact(f, x=k);
# Out:
# interactive(children=(Dropdown(description='x', options=('cryptochlorogenic acid', 'chlorogenic acid', 'catech…

# %% [markdown]
# # Spodaj so samo testi
# ##to pa je običajno besedilo

# %%
Anka = pd.read_excel (r"O:\Naprave\Agrosta Wonderful-in drugi\X-Anka japka\Polifenoli Anka 18022020_3.xlsx", 0) #bere file
#dva = Zid.loc[(Zid['IZLOCITI'] == 0) ] # izloci oznacene
dd=pd.unique(Anka["meso"])
print(dd)
meso = Anka.loc[(Anka['meso'] == 'meso') ]#  izloči kar ni zanimivo & (orders['Blok (Rimske I-VIII)'] == 'I')]
kozica = Anka.loc[(Anka['meso'] == 'kožica')]
list = Anka.loc[(Anka['meso'] == 'list')]

k = ['sum of hydroxycinnamic acids', 'sum of dihydrochalcones',
       'sum of flavonols', 'sum of flavanols' #'cy3_1gal'] #izberemo katere parametre želimo računati - Glej kaj natisne "h"
        ]
x=meso['sum of flavanols']
y=meso['sum of hydroxycinnamic acids']


fig,a =  plt.subplots(nrows=2, ncols=2, figsize=(9, 4))
import numpy as np
x = np.arange(1,5)
a[0][0].boxplot(meso['sum of hydroxycinnamic acids'],
    vert=True,  # vertical box alignment
    patch_artist=True,  # fill with color
    labels=pd.unique(meso["C-L"]))  # will be used to label x-ticks
                
#sns.boxplot(x="sorta", y=yy, hue="C-L", data=meso, palette="Set3", ax=ax) #plot(x,x*x) 
a[0][0].set_title('square')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('square root')
a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')
plt.show()

# fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# # rectangular box plot
# bplot1 = ax1.boxplot(all_data,
#                      vert=True,  # vertical box alignment
#                      patch_artist=True,  # fill with color
#                      labels=labels)  # will be used to label x-ticks
# ax1.set_title('Rectangular box plot')


#interact(f, x=k, dd=m);
# Out:
# ['meso' 'kožica' 'list']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-49bf72b379c8> in <module>
#      20     vert=True,  # vertical box alignment
#      21     patch_artist=True,  # fill with color
# ---> 22     labels=pd.unique(meso["C-L"]))  # will be used to label x-ticks
#      23
#      24 #sns.boxplot(x="sorta", y=yy, hue="C-L", data=meso, palette="Set3", ax=ax) #plot(x,x*x)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3668
#    3669         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
# -> 3670                                        labels=labels, autorange=autorange)
#    3671         if notch is None:
#    3672             notch = rcParams['boxplot.notch']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1249         labels = itertools.repeat(None)
#    1250     elif len(labels) != ncols:
# -> 1251         raise ValueError("Dimensions of labels and X must be compatible")
#    1252
#    1253     input_whis = whis
#
# ValueError: Dimensions of labels and X must be compatible

# %%
Ank = Anka
for x in k:
   ll = Ank[x] #da kličemo vsak stolpec
   nn = 'Meso_Sorta-cas-lokacija.' + ll.name +'.png'# naredimo string za poimenovanje datotek
   InLop = Ank.loc[(Ank[x] > 0)] #izbere samo tiste ki so večje od 0 - izloči besedilo
   #m = sum(InLop[x]) / len(InLop[x]) #povprečje
   #print(m)
   print(len(InLop[x]))
   yy=InLop[x]
   #print(ena[x])
     ## RIŠE BOXPLOT
   plt.close() #zapre vsak graf od prej
   fig, ax = plt.subplots()
   sns.boxplot(x="sorta", y=yy, hue="C-L", data=InLop, palette="Set3", ax=ax)  #hue="meso",
   plt.show() #prikaže vsak graf
   #fig = bp.get_figure()  # da graf v objekt fig
   print(nn)  # v  log izpiše ime grafa ki ga je naredil
   fig.savefig(nn)  # shrani graf pod imenom "nn"
# Out:
# 53
# Meso_Sorta-cas-lokacija.cryptochlorogenic acid.png
# 80
# Meso_Sorta-cas-lokacija.chlorogenic acid.png
# 68
# Meso_Sorta-cas-lokacija.catechin.png
# 73
# Meso_Sorta-cas-lokacija.epicatechin.png
# 50
# Meso_Sorta-cas-lokacija.neochlorogenic acid.png
# 80
# Meso_Sorta-cas-lokacija.Phlorizin.png
# 58
# Meso_Sorta-cas-lokacija.Procyanidin B1.png
# 61
# Meso_Sorta-cas-lokacija.procyanidin B2_B4.png
# 79
# Meso_Sorta-cas-lokacija.Quercetin_13_1Rha.png
# 61
# Meso_Sorta-cas-lokacija.quercetin-13-1Glc_Gal.png
# 59
# Meso_Sorta-cas-lokacija.p_1coumaric acid.png
# 80
# Meso_Sorta-cas-lokacija.Phloretin Xylo Glc.png
# 30
# Meso_Sorta-cas-lokacija.3_1Hydroxyphloretin.png
# 43
# Meso_Sorta-cas-lokacija.3_1hydroxy_1Phlorizin.png
# 80
# Meso_Sorta-cas-lokacija.sum of hydroxycinnamic acids.png
# 80
# Meso_Sorta-cas-lokacija.sum of dihydrochalcones.png
# 80
# Meso_Sorta-cas-lokacija.sum of flavonols.png
# 76
# Meso_Sorta-cas-lokacija.sum of flavanols.png

# %%
plt.boxplot(meso['sum of hydroxycinnamic acids'],
    vert=True,  # vertical box alignment
    patch_artist=True,  # fill with color
    labels=meso["C-L"])  # will be used to label x-ticks
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-37a861eea744> in <module>
#       2     vert=True,  # vertical box alignment
#       3     patch_artist=True,  # fill with color
# ----> 4     labels=meso["C-L"])  # will be used to label x-ticks
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2471         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2472         autorange=autorange, zorder=zorder, **({"data": data} if data
# -> 2473         is not None else {}))
#    2474
#    2475
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     305                 f"for the old name will be dropped %(removal)s.")
#     306             kwargs[new] = kwargs.pop(old)
# --> 307         return func(*args, **kwargs)
#     308
#     309     # wrapper() must keep the same documented signature as func(): if we
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3668
#    3669         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
# -> 3670                                        labels=labels, autorange=autorange)
#    3671         if notch is None:
#    3672             notch = rcParams['boxplot.notch']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1249         labels = itertools.repeat(None)
#    1250     elif len(labels) != ncols:
# -> 1251         raise ValueError("Dimensions of labels and X must be compatible")
#    1252
#    1253     input_whis = whis
#
# ValueError: Dimensions of labels and X must be compatible
